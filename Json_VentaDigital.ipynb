# %% [markdown]
# # LECTURA DE API

# %%
import requests
import json
import pandas as pd
import csv
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\parentpoller.py:116: UserWarning: Parent poll failed.  If the frontend dies,
#                 the kernel may be left running.  Please let us know
#                 about your system (bitness, Python, etc.) at
#                 ipython-dev@scipy.org
#   ipython-dev@scipy.org""")

# %%
#200 -- everything went okay, and the result has been returned (if any)
#301 -- the server is redirecting you to a different endpoint. This can happen when a company switches domain names, or an endpoint name is changed.
#401 -- the server thinks you're not authenticated. This happens when you don't send the right credentials to access an API (we'll talk about authentication in a later post).
#400 -- the server thinks you made a bad request. This can happen when you don't send along the right data, among other things.
#403 -- the resource you're trying to access is forbidden -- you don't have the right permissions to see it.
#404 -- the resource you tried to access wasn't found on the server.

# %%
# ESTA ES NUESTRO LINK :) 

#Detalle de los parámetros

#http://s340vd1:9080/halcon-servicio-rest-portlet/rest/dataVentaDigital/[#FECHA_DESDE#]/[#FECHA_HASTA#]/[#CODIGO_SIEBEL#]/[#NUMERO_PAGINA#]

#1.- [#FECHA_DESDE#] = dd-MM-yyyy

#2.- [#FECHA_HASTA#] = dd-MM-yyyy

#3.- [#CODIGO_SIEBEL#] = Los códigos siebel lo ubicas en gestión de parámetros el nombre para buscarlos es "venta"

#Venta Digital    
cosafea = requests.get("http://s340vd1:9080/halcon-servicio-rest-portlet/rest/dataVentaDigital/10-10-2000/10-10-2018/0/1", auth=('gobdatos01', 'gobdatos01'))

#Inscripcion
#cosafea = requests.get("http://s340vp23:9080/halcon-servicio-rest-portlet/rest/formularioInscripcion/28-03-2019/29-03-2019/0/1", auth=('gobdatos01', 'gobdatos01'))
print(cosafea.status_code)
# Out:
# 200

# %%
cosafea.headers['content-type']
# 'application/json'
# Out:
# 'application/json;charset=UTF-8'

# %%
cosafea
# Out:
# <Response [200]>

# %%
jsonfeo = cosafea.json()
print(jsonfeo)
# Out:
# {'messageCode': 200, 'message': 'success', 'body': {'paginacion': {'totalRegistros': 26519, 'totalPaginas': 6, 'cantPorPagina': 5000, 'paginaActual': 1, 'start': 1, 'end': 5000}, 'listFormularioInscripcion': [{'num': 1, 'tipodocumento': '01', 'numerodocumento': '09784507', 'celular': '', 'email': '', 'estadoLpd': '0', 'fecha': '2019-03-29 08:14:02.61', 'codigo': '201904_COPA'}, {'num': 2, 'tipodocumento': '01', 'numerodocumento': '09783026', 'celular': '', 'email': '', 'estadoLpd': '0', 'fecha': '2019-03-28 08:06:19.603', 'codigo': '201904_COPA'}, {'num': 3, 'tipodocumento': '01', 'numerodocumento': '09783104', 'celular': '', 'email': '', 'estadoLpd': '0', 'fecha': '2019-03-28 10:01:41.967', 'codigo': '201904_COPA'}, {'num': 4, 'tipodocumento': '01', 'numerodocumento': '09783953', 'celular': '', 'email': '', 'estadoLpd': '0', 'fecha': '2019-03-28 11:08:17.79', 'codigo': '201904_COPA'}, {'num': 5, 'tipodocumento': '01', 'numerodocumento': '09794683', 'celular': '', 'email': '', 'estadoLpd': '0', 'fecha': '2019-03-28 13:14:18.837', 'codigo': '201904_COPA'}, {'num': 6, 'tipodocumento': '01', 'numerodocumento': '09796050', 'celular': '', 'email': '', 'estadoLpd': '0', 'fecha': '2019-03-28 12:31:08.997', 'codigo': '201904_COPA'}, {'num': 7, 'tipodocumento': '01', 'numerodocumento': '09800213', 'celular': '', 'email': '', 'estadoLpd': '0', 'fecha': '2019-03-29 07:30:55.257', 'codigo': '201904_COPA'}, {'num': 8, 'tipodocumento': '01', 'numerodocumento': '09796494', 'celular': '', 'email': '', 'estadoLpd': '0', 'fecha': '2019-03-28 16:19:24.743', 'codigo': '201904_COPA'}, {'num': 9, 'tipodocumento': '01', 'numerodocumento': '09806839', 'celular': '', 'email': '', 'estadoLpd': '0', 'fecha': '2019-03-28 08:49:28.85', 'codigo': '201904_COPA'}, {'num': 10, 'tipodocumento': '01', 'numerodocumento': '09798814', 'celular': '', 'email': '', 'estadoLpd': '0', 'fecha': '2019-03-28 07:38:54.427', 'codigo': '201904_COPA'}, {'num': 11, 'tipodocumento': '01', 'numerodocumento': '09825700', 'celular': '', 'email': '', 'estadoLpd': '0', 'fecha': '2019-03-28 08:12:05.213', 'codigo': '201904_COPA'}, {'num': 12, 'tipodocumento': '01', 'numerodocumento': '09826575', 'celular': '', 'email': '', 'estadoLpd': '0', 'fecha': '2019-03-28 09:28:26.843', 'codigo': '201904_COPA'}, {'num': 13, 'tipodocumento': '01', 'numerodocumento': '09827095', 'celular': '', 'email': '', 'estadoLpd': '0', 'fecha': '2019-03-28 21:46:14.963', 'codigo': '201904_COPA'}, {'num': 14, 'tipodocumento': '01', 'numerodocumento': '09829827', 'celular': '', 'email': '', 'estadoLpd': '0', 'fecha': '2019-03-29 07:01:21.46', 'codigo': '201904_COPA'}, {'num': 15, 'tipodocumento': '01', 'numerodocumento': '09836589', 'celular': '', 'email': '', 'estadoLpd': '0', 'fecha': '2019-03-29 07:32:08.307', 'codigo': '201904_COPA'}, {'num': 16, 'tipodocumento': '01', 'numerodocumento': '09838559', 'celular': '', 'email': '', 'estadoLpd': '0', 'fecha': '2019-03-29 01:20:29.377', 'codigo': '201904_COPA'}, {'num': 17, 'tipodocumento': '01', 'numerodocumento': '09839921', 'celular': '', 'email': '', 'estadoLpd': '0', 'fecha': '2019-03-28 17:21:06.027', 'codigo': '201904_COPA'}, {'num': 18, 'tipodocumento': '01', 'numerodocumento': '09840752', 'celular': '', 'email': '', 'estadoLpd': '0', 'fecha': '2019-03-28 19:07:48.75', 'codigo': '201904_COPA'}, {'num': 19, 'tipodocumento': '01', 'numerodocumento': '09843834', 'celular': '', 'email': '', 'estadoLpd': '0', 'fecha': '2019-03-28 10:00:02.21', 'codigo': '201904_COPA'}, {'num': 20, 'tipodocumento': '01', 'numerodocumento': '09851660', 'celular': '', 'email': '', 'estadoLpd': '0', 'fecha': '2019-03-28 10:53:50.717', 'codigo': '201904_COPA'}, {'num': 21, 'tipodocumento': '01', 'numerodocumento': '09852583', 'celular': '', 'email': '', 'estadoLpd': '0', 'fecha': '2019-03-28 10:57:28.78', 'codigo': '201904_COPA'}, {'num': 22, 'tipodocumento': '01', 'numerodocumento': '09855821', 'celular': '', 'email': '', 'estadoLpd': '0', 'fecha': '2019-03-28 12:47:41.417', 'codi ...

# %%
type(jsonfeo)
# Out:
# dict

# %%
# ESTO ES PARA GRABAR UN JSON :) 

def writeToJSONFile(path, fileName, data):
    filePathNameWExt = './' + path + '/' + fileName + '.json'
    with open(filePathNameWExt, 'w') as fp:
        json.dump(data, fp)
        
writeToJSONFile('./','input_json_venta_api',jsonfeo)

# %% [markdown]
# # DESDE AQUI VIENE EL TRATAMIENTO PARA LEER BIEN
#
# # EL JSON QUE TE TRAE EL API

# %%
# FORMA 1 QUE NO VOY A USAR PORQUE NO ME SIRVE DE NADA 
#jsonfeo['listVentaDigital']

#data_aqui = jsonfeo['listVentaDigital']

#data_aqui[5]


### CARGA MALVADA CUANDO NO ES DATAFRAME
### SE CAMBIO LA ESTRUCTURA ANTERIOR QUE YA ESTABA HECHA 

# Venta_halcon = open('Json_Venta_OtroFormato.csv', 'w')

# create the csv writer object

#csvwriter = csv.writer(Venta_halcon)

#count = 0

#for emp in data_aqui:
#      if count == 0:
#             header = emp.keys()
#             csvwriter.writerow(header)
#             count += 1
#      csvwriter.writerow(emp.values())

#Venta_halcon.close()

# %%
# La data que guarde la abrire con panda y la volvere JSON y eso un Data frame
# No lo hago del json de arriba xk DIOS SABE porque me sale error :) 

data = json.load(open('input_json_venta_api.json'))

listVentaDigital = pd.DataFrame(data["listVentaDigital"])

listVentaDigital
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-2e4379439309> in <module>()
#       4 data = json.load(open('input_json_venta_api.json'))
#       5
# ----> 6 listVentaDigital = pd.DataFrame(data["listVentaDigital"])
#       7
#       8 listVentaDigital
#
# KeyError: 'listVentaDigital'

# %% [markdown]
# # PARA PASAR AL CSV :)

# %%
# AQUI LO BAJO A CSV PORQUE PUEDO :) 

listVentaDigital.to_csv('venta_digital_halcon_out_api.csv', sep='|', encoding='utf-8',index=False)

# %% [markdown]
# # INTENTO DE PASAR A ORACLE

# %%
# Conectar a Oracle
import cx_Oracle

# %%
db = cx_Oracle.connect('DWHAC', 'USRDW159', 'IBFDMP')

# %%
# Conectar a Oracle de otra forma
import pyodbc as pio

pio.dataSources()

# nn_ora = pio.connect(dsn="Oracle_DWHAC", database="IBFDMP",uid="DWHAC",pwd="USRDW159")
# conexionORCL = odbcConnect("IBFDMP", uid="DWHAC", pwd="USRDW159", rows_at_time = 500)
# Out:
# {'Excel Files': 'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)',
#  'MS Access Database': 'Microsoft Access Driver (*.mdb, *.accdb)',
#  'DSN Teradata': 'Teradata',
#  'Oracle_DWHAC': 'Oracle en OraClient11g_home1',
#  'R_for_Aster': 'Aster ODBC Driver'}

# %%
conn_ora = pio.connect(url="jdbc:oracle:thin:@s139vp16.grupoib.local:1521:IBFDMP", database="IBFDMP",uid="DWHAC", PWD='USRDW159')

jdbc:oracle:thin:@s139vp16.grupoib.local:1521:IBFDMP
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# <ipython-input-34-1a6f4b333485> in <module>()
# ----> 1 conn_ora = pio.connect(url="jdbc:oracle:thin:@s139vp16.grupoib.local:1521:IBFDMP", database="IBFDMP",uid="DWHAC", PWD='USRDW159')
#
# InterfaceError: ('IM002', '[IM002] [Microsoft][Administrador de controladores ODBC] No se encuentra el nombre del origen de datos y no se especificó ningún controlador predeterminado (0) (SQLDriverConnect)')

# %%
table = pd.read_sql("select count(1) from dwhac.dgov_maestra_geolocalizacion limit 2", conn_ora)
table.head(5)

# %%
import sqlalchemy

engine = create_engine('oracle://scott:tiger@127.0.0.1:1521/sidname')
engine = create_engine('oracle+cx_oracle://scott:tiger@tnsname')

# %% [markdown]
# # INTENTO DE PASAR A ORACLE O ASTER

# %%
# Conectar a traves de ODBC
import pyodbc as pio

conn = pio.connect(dsn="R_for_Aster",server="10.11.9.81",database="ibk",uid="ccastrov",pwd="ccastrov1")
 
table = pd.read_sql("select count(1) from crm_analitico.CC_AdobeIDxSegmentacion limit 2", conn)
table.head(5)
# Out:
#    count(1)
# 0   3301095

# %%
import sqlalchemy

url_sql = sqlalchemy.engine.url.URL("Oracle_DWHAC", username="DWHAC", password="USRDW159" )
url_sql
# Out:
# Oracle_DWHAC://DWHAC:***@

# %%
import sqlalchemy

url_sql = sqlalchemy.engine.url.URL("R_for_Aster", username="ccastrov", password="ccastrov1" )
url_sql
# Out:
# R_for_Aster://ccastrov:***@

# %%
engine = sqlalchemy.create_engine(url_sql)
# Out:
# ---------------------------------------------------------------------------
# NoSuchModuleError                         Traceback (most recent call last)
# <ipython-input-715-c9dc468e925b> in <module>()
# ----> 1 engine = sqlalchemy.create_engine(url_sql)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\__init__.py in create_engine(*args, **kwargs)
#     422     strategy = kwargs.pop('strategy', default_strategy)
#     423     strategy = strategies.strategies[strategy]
# --> 424     return strategy.create(*args, **kwargs)
#     425
#     426
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in create(self, name_or_url, **kwargs)
#      55         kwargs.pop('plugins', None)
#      56
# ---> 57         entrypoint = u._get_entrypoint()
#      58         dialect_cls = entrypoint.get_dialect_cls(u)
#      59
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\url.py in _get_entrypoint(self)
#     154         else:
#     155             name = self.drivername.replace('+', '.')
# --> 156         cls = registry.load(name)
#     157         # check for legacy dialects that
#     158         # would return a module with 'dialect' as the
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in load(self, name)
#     219         raise exc.NoSuchModuleError(
#     220             "Can't load plugin: %s:%s" %
# --> 221             (self.group, name))
#     222
#     223     def register(self, name, modulepath, objname):
#
# NoSuchModuleError: Can't load plugin: sqlalchemy.dialects:R_for_Aster

# %%
cur = conn.cursor()

borrame = "drop table if exists crm_analitico.CC_AdobeIDxSegmentacion;"
cur.execute(borrame)
creame = "CREATE TABLE crma_analitico.cc_holiwi_prueba ( "
creame = creame + " ) DISTRIBUTE BY HASH (NOMTABLA) compress low; "


	CODMES bigint ,
	NOMESQUEMA varchar(10),
	NOMTABLA varchar(250),
	CODMES_TIENE bigint,
	CODMES_6MENOS BIGINT,
	CODMES_1MENOS BIGINT,
	CODMES_1MAS BIGINT,
	CODMES_4MENOS BIGINT,
	CODMES_3MENOS BIGINT,
	FECHA_ACTUALIZACION  date


con.commit()

creame
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-638-ea21dd6d2ec2> in <module>()
#       1 cur = conn.cursor()
#       2 string = "CREATE TABLE TestTable(symbol varchar(15), leverage double, shares integer, price double)"
# ----> 3 cur.execute(string)
#       4 con.commit()
#
# ProgrammingError: ('42000', '[42000] [AsterData][nCluster] (34) ERROR: DISTRIBUTE BY clause not specified.  (34) (SQLExecDirectW)')
