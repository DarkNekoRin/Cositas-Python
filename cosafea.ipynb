# %% [markdown]
# # LECTURA DE API

# %%
import requests
import json
import pandas as pd

# EJEMPLO PARA VER COMO FUNCIONA
# Make a get request to get the latest position of the international space station from the opennotify api.
response = requests.get("http://api.open-notify.org/iss-now.json")

# %%
# Print the status code of the response.
print(response.status_code)

#200 -- everything went okay, and the result has been returned (if any)
#301 -- the server is redirecting you to a different endpoint. This can happen when a company switches domain names, or an endpoint name is changed.
#401 -- the server thinks you're not authenticated. This happens when you don't send the right credentials to access an API (we'll talk about authentication in a later post).
#400 -- the server thinks you made a bad request. This can happen when you don't send along the right data, among other things.
#403 -- the resource you're trying to access is forbidden -- you don't have the right permissions to see it.
#404 -- the resource you tried to access wasn't found on the server.
# Out:
# 200

# %%
# probar con algo que no existe 
response = requests.get("http://api.open-notify.org/iss-pass")
print(response.status_code)
# Out:
# 404

# %%
# ESTA ES NUESTRO LINK :) 

#cosafea = requests.get("http://s340vd1:9080/api/jsonws/formulario-dinamico-portlet.formularioregistrodinamico/get-listar-registros-fb?valor=codigo01,codigo02", auth=('test', 'test'))
#print(cosafea.status_code)


cosafea = requests.get("http://s340vp22:9080/api/jsonws/formulario-dinamico-portlet.formularioregistrodinamico/get-listar-registros-fb?valor=201901_VERANO,201901_GRIFOS", auth=('mromerola', 'V#qTnxsYVkMzjf22FiH'))
print(cosafea.status_code)
# Out:
# 200

# %%
cosafea.headers['content-type']
# 'application/json'
# Out:
# 'application/json'

# %%
cosafea
# Out:
# <Response [200]>

# %%
jsonfeo = cosafea.json()
print(jsonfeo)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
type(jsonfeo)
# Out:
# str

# %%
# ESTO ES PARA GRABAR UN JSON :) 

def writeToJSONFile(path, fileName, data):
    filePathNameWExt = './' + path + '/' + fileName + '.json'
    with open(filePathNameWExt, 'w') as fp:
        json.dump(data, fp)
        
writeToJSONFile('./','input_json_api',jsonfeo)

# %%
type(cosafea.json())
# Out:
# str

# %%
holi = pd.read_json(cosafea.json())

# %%
holi
# Out:
#                                         head  \
# listarLlamadaAutomatica                  NaN
# message                              Success
# messageId                                200
# timestamp                2019-02-06 12:21:19
#
#                                                                       body
# listarLlamadaAutomatica  [[Formulario, CodigoFB, DNI, Fecha], [Grifos, ...
# message                                                                NaN
# messageId                                                              NaN
# timestamp                                                              NaN

# %% [markdown]
# # DESDE AQUI VIENE EL TRATAMIENTO PARA LEER BIEN
#
# # EL JSON QUE TE TRAE EL API

# %%
lista = holi.loc["listarLlamadaAutomatica"]
lista
# Out:
# head                                                  NaN
# body    [[Formulario, CodigoFB, DNI, Fecha], [Grifos, ...
# Name: listarLlamadaAutomatica, dtype: object

# %%
data= lista[1]
data
# Out:
# ['[Formulario, CodigoFB, DNI, Fecha]',
#  '[Grifos, 201901_VERANO, 46581878, 24/12/2018]',
#  '[Grifos, 201901_VERANO, 70437419, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 47147262, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 47147262, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 70767752, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 42267417, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 41183845, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 10628472, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 10282107, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 46581878, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 70476084, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 44228275, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 45129712, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 41688423, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 72928534, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 41145501, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 42745830, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 45747883, 26/12/2018]',
# ...

# %%
# ESTO ES LA CABECERA
data[0]
# Out:
# '[Formulario, CodigoFB, DNI, Fecha]'

# %%
# PARA ENTENDER QUE TENGO CABECERA Y CUERPO (RESTO)
columna = data[0]
resto = data[1:]

# %%
# ver primer valor de la data
resto[0]
# Out:
# '[Grifos, 201901_VERANO, 46581878, 24/12/2018]'

# %%
# ver segundo valor de la data
resto[1]
# Out:
# '[Grifos, 201901_VERANO, 47147262, 26/12/2018]'

# %%
# esto lo hago para quitar las []
columna2 = columna.strip('[]')

# para hacer columnas por cada , 
cabecerabb = columna2.split(',')
cabecerabb
# Out:
# ['Formulario', ' CodigoFB', ' DNI', ' Fecha']

# %%
# Cabecerabb es lo que voy a utilizar :) para nombrar las columnas
# vamos a ver que tipo es 

type(cabecerabb)
# Out:
# list

# %%
resto
# Out:
# ['[Grifos, 201901_VERANO, 46581878, 24/12/2018]',
#  '[Grifos, 201901_VERANO, 47147262, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 70437419, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 70767752, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 42267417, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 47147262, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 72928534, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 41183845, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 10681543, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 10628472, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 45158752, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 06782311, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 10282107, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 46581878, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 44241260, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 45607021, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 46618928, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 46922378, 26/12/2018]',
#  '[Grifos, 201901_VERANO, 70476084, 26/12/2018]',
# ...

# %%
# la funcion de arriba tmbn nos servira para todo el cuerpo

resto[0].strip('[]').split(',')
# Out:
# ['Grifos', ' 201901_VERANO', ' 46581878', ' 24/12/2018']

# %%
# DEMOSTRANDO QUE SE CREAR UN ELEMENTO DE LSITA PARA CADA COSA
a,b,c,d =  resto[0].strip('[]').split(',')  
a, b , c, d
# Out:
# ('Grifos', ' 201901_VERANO', ' 46581878', ' 24/12/2018')

# %%
# TENGO QUE CREAR UN DATAFRAME VACIO
# ESTO LO USARE PARA TENER EL JSON ADENTRO

rr = pd.DataFrame(pd.np.empty((0, 4)))
rr
# Out:
# Empty DataFrame
# Columns: [0, 1, 2, 3]
# Index: []

# %%
for i in range(len(resto)): 
    #temp = pd.DataFrame( resto[i].strip('[]').split(',')  )
    rr.loc[i] = resto[i].strip('[]').split(',')
    #holi = pd.DataFrame( temp.transpose() ) 

    
rr
# Out:
#                             0               1          2            3
# 0                      Grifos   201901_VERANO   46581878   24/12/2018
# 1                      Grifos   201901_VERANO   47147262   26/12/2018
# 2                      Grifos   201901_VERANO   70437419   26/12/2018
# 3                      Grifos   201901_VERANO   70767752   26/12/2018
# 4                      Grifos   201901_VERANO   42267417   26/12/2018
# 5                      Grifos   201901_VERANO   47147262   26/12/2018
# 6                      Grifos   201901_VERANO   72928534   26/12/2018
# 7                      Grifos   201901_VERANO   41183845   26/12/2018
# 8                      Grifos   201901_VERANO   10681543   26/12/2018
# 9                      Grifos   201901_VERANO   10628472   26/12/2018
# 10                     Grifos   201901_VERANO   45158752   26/12/2018
# 11                     Grifos   201901_VERANO   06782311   26/12/2018
# ...

# %%
#HOLA SOY UN PIVOTE :) 
# QUIEREME 
#df = pd.DataFrame(temp, index=temp, columns=cabecerabb)
#df

# %%
# mega importante :
# RENOMBRO EL NOMBRE DE LAS COLUMNAS
# tengo que hacer estoa  este paso porque si lo creo con nombre de columnas 
# la data saldra NaN es mejor hacerlo al final :) 

rr.columns = cabecerabb

# %%
rr
# Out:
#                    Formulario        CodigoFB        DNI        Fecha
# 0                      Grifos   201901_VERANO   46581878   24/12/2018
# 1                      Grifos   201901_VERANO   47147262   26/12/2018
# 2                      Grifos   201901_VERANO   70437419   26/12/2018
# 3                      Grifos   201901_VERANO   70767752   26/12/2018
# 4                      Grifos   201901_VERANO   42267417   26/12/2018
# 5                      Grifos   201901_VERANO   47147262   26/12/2018
# 6                      Grifos   201901_VERANO   72928534   26/12/2018
# 7                      Grifos   201901_VERANO   41183845   26/12/2018
# 8                      Grifos   201901_VERANO   10681543   26/12/2018
# 9                      Grifos   201901_VERANO   10628472   26/12/2018
# 10                     Grifos   201901_VERANO   45158752   26/12/2018
# 11                     Grifos   201901_VERANO   06782311   26/12/2018
# ...

# %% [markdown]
# # PARA PASAR AL CSV :)

# %%
# AQUI LO BAJO A CSV PORQUE PUEDO :) 

rr.to_csv('out_api.csv', sep='|', encoding='utf-8',index=False)

# %% [markdown]
# # INTENTO DE PASAR A ORACLE

# %%
# Conectar a Oracle
import cx_Oracle

# %%
db = cx_Oracle.connect('DWHAC', 'USRDW159', 'IBFDMP')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-f3757d4cbb3f> in <module>()
# ----> 1 db = cx_Oracle.connect('DWHAC', 'USRDW159', 'IBFDMP')
#
# NameError: name 'cx_Oracle' is not defined

# %%
# Conectar a Oracle de otra forma
import pyodbc as pio

pio.dataSources()

# nn_ora = pio.connect(dsn="Oracle_DWHAC", database="IBFDMP",uid="DWHAC",pwd="USRDW159")
# conexionORCL = odbcConnect("IBFDMP", uid="DWHAC", pwd="USRDW159", rows_at_time = 500)
# Out:
# {'Excel Files': 'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)',
#  'MS Access Database': 'Microsoft Access Driver (*.mdb, *.accdb)',
#  'DSN Teradata': 'Teradata',
#  'Oracle_DWHAC': 'Oracle en OraClient11g_home1',
#  'R_for_Aster': 'Aster ODBC Driver'}

# %%
conn_ora = pio.connect(url="jdbc:oracle:thin:@s139vp16.grupoib.local:1521:IBFDMP", database="IBFDMP",uid="DWHAC", PWD='USRDW159')

jdbc:oracle:thin:@s139vp16.grupoib.local:1521:IBFDMP
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# <ipython-input-34-1a6f4b333485> in <module>()
# ----> 1 conn_ora = pio.connect(url="jdbc:oracle:thin:@s139vp16.grupoib.local:1521:IBFDMP", database="IBFDMP",uid="DWHAC", PWD='USRDW159')
#
# InterfaceError: ('IM002', '[IM002] [Microsoft][Administrador de controladores ODBC] No se encuentra el nombre del origen de datos y no se especificó ningún controlador predeterminado (0) (SQLDriverConnect)')

# %%
table = pd.read_sql("select count(1) from dwhac.dgov_maestra_geolocalizacion limit 2", conn_ora)
table.head(5)

# %%
import sqlalchemy

engine = create_engine('oracle://scott:tiger@127.0.0.1:1521/sidname')
engine = create_engine('oracle+cx_oracle://scott:tiger@tnsname')

# %% [markdown]
# # INTENTO DE PASAR A ORACLE O ASTER

# %%
# Conectar a traves de ODBC
import pyodbc as pio

conn = pio.connect(dsn="R_for_Aster",server="10.11.9.81",database="ibk",uid="ccastrov",pwd="ccastrov1")
 
table = pd.read_sql("select count(1) from crm_analitico.CC_AdobeIDxSegmentacion limit 2", conn)
table.head(5)
# Out:
#    count(1)
# 0   3301095

# %%
import sqlalchemy

url_sql = sqlalchemy.engine.url.URL("Oracle_DWHAC", username="DWHAC", password="USRDW159" )
url_sql
# Out:
# Oracle_DWHAC://DWHAC:***@

# %%
import sqlalchemy

url_sql = sqlalchemy.engine.url.URL("R_for_Aster", username="ccastrov", password="ccastrov1" )
url_sql
# Out:
# R_for_Aster://ccastrov:***@

# %%
engine = sqlalchemy.create_engine(url_sql)
# Out:
# ---------------------------------------------------------------------------
# NoSuchModuleError                         Traceback (most recent call last)
# <ipython-input-715-c9dc468e925b> in <module>()
# ----> 1 engine = sqlalchemy.create_engine(url_sql)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\__init__.py in create_engine(*args, **kwargs)
#     422     strategy = kwargs.pop('strategy', default_strategy)
#     423     strategy = strategies.strategies[strategy]
# --> 424     return strategy.create(*args, **kwargs)
#     425
#     426
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in create(self, name_or_url, **kwargs)
#      55         kwargs.pop('plugins', None)
#      56
# ---> 57         entrypoint = u._get_entrypoint()
#      58         dialect_cls = entrypoint.get_dialect_cls(u)
#      59
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\url.py in _get_entrypoint(self)
#     154         else:
# ...

# %%
cur = conn.cursor()

borrame = "drop table if exists crm_analitico.CC_AdobeIDxSegmentacion;"
cur.execute(borrame)
creame = "CREATE TABLE crma_analitico.cc_holiwi_prueba ( "
creame = creame + " ) DISTRIBUTE BY HASH (NOMTABLA) compress low; "


	CODMES bigint ,
	NOMESQUEMA varchar(10),
	NOMTABLA varchar(250),
	CODMES_TIENE bigint,
	CODMES_6MENOS BIGINT,
	CODMES_1MENOS BIGINT,
	CODMES_1MAS BIGINT,
	CODMES_4MENOS BIGINT,
	CODMES_3MENOS BIGINT,
	FECHA_ACTUALIZACION  date


con.commit()

creame
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-638-ea21dd6d2ec2> in <module>()
#       1 cur = conn.cursor()
#       2 string = "CREATE TABLE TestTable(symbol varchar(15), leverage double, shares integer, price double)"
# ----> 3 cur.execute(string)
#       4 con.commit()
#
# ProgrammingError: ('42000', '[42000] [AsterData][nCluster] (34) ERROR: DISTRIBUTE BY clause not specified.  (34) (SQLExecDirectW)')
